# %% [markdown]
# PROJECT 4

# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %% [markdown]
# Display data

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# getting info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# statistical description

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Data filtering

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sum(data['Sex']=="male")
# Out:
# 577

# %%
sum(data['Survived']==1)
# Out:
# 342

# %% [markdown]
# checking null values

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# drop the columns

# %%
data.drop('Cabin', axis=1, inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# handle missing values

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %% [markdown]
# filling missing values

# %%
data['Embarked'].fillna("S", inplace=True)

# %% [markdown]
# handling missing values of age column

# %%
data['Age'].fillna(data['Age'].mean() , inplace=True)

# %% [markdown]
# checking null values

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Categorical data encoding
#
#
# for  sex and embarked columns
# as infuture for machine learning these string values
# cannot be undertood by them so we have to encode it.
#
# check category of every column before encoding

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['gender'] = data['Sex'].map({'male': 1, 'female' : 0})
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Embarked  gender
# 0      0         A/5 21171   7.2500        S       1
# 1      0          PC 17599  71.2833        C       0
# 2      0  STON/O2. 3101282   7.9250        S       0

# %% [markdown]
# adding the newly added column in a specific place

# %%
x = data['Sex'].map({'male': 1, 'female' : 0})

# %%
data.insert(5,'Gender',x)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender  \
# 0                              Braund, Mr. Owen Harris    male       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       0
# 2                               Heikkinen, Miss. Laina  female       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       0
# 4                             Allen, Mr. William Henry    male       1
# ..                                                 ...     ...     ...
# ...

# %% [markdown]
# Encode for categories  more than two
#
# like here we have 3 categories in embarked column

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %% [markdown]
# we use get dummies for encoding more than two categories
# it creates different columns equals to the number of categories
# by default the new cloumn is in bool dtype
# to change the dtype we give the argument dtype=int

# %%
pd.get_dummies(data, columns=['Embarked'], dtype=int)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender  \
# 0                              Braund, Mr. Owen Harris    male       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       0
# 2                               Heikkinen, Miss. Laina  female       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       0
# 4                             Allen, Mr. William Henry    male       1
# ..                                                 ...     ...     ...
# ...

# %% [markdown]
# we can predict the 1 category by comparing the other two categories like in first row we see S & Q as 1 & 0 means the C will be 0
# so we can remove one category as we can predict it by using other two categories

# %%
encoded_data = pd.get_dummies(data, columns=['Embarked'], dtype=int, drop_first=True)

# %% [markdown]
# how many people survived and how many died

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(data['Survived'].value_counts())
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# how many passengers were in each class

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.barplot(data['Pclass'].value_counts())
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# number of male and female passengers

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.barplot(data['Sex'].value_counts())
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# using plt in age column because it is a numerical column
# not a categorial column

# %%
plt.hist(data['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# barplot of countplot is used for categorial columns
# histograms and box plot are used for continous variable
# to show frequency

# %% [markdown]
# bivariate analysis

# %% [markdown]
# who has better chance of survival male or female ?

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'gender'],
#       dtype='object')

# %%
sns.barplot(x='Sex', y='Survived', data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# which pclass has better chance of survival

# %%
sns.barplot(x='Pclass', y='Survived', data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# feature engineering
#
# to extract features from raw data via using data mining techniques

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'gender'],
#       dtype='object')

# %% [markdown]
# using the columns 'SibSp', 'Parch' we can know the size of a persons family
#
# lets combine these two columnns

# %%
data['family_size'] = data['SibSp'] + data['Parch']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender  \
# 0                              Braund, Mr. Owen Harris    male       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       0
# 2                               Heikkinen, Miss. Laina  female       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       0
# 4                             Allen, Mr. William Henry    male       1
# ..                                                 ...     ...     ...
# ...
