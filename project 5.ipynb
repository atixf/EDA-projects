# %% [markdown]
# Google play store apps

# %%
import pandas as pd

# %%
data = pd.read_csv("googleplaystore.csv")

# %% [markdown]
# basic operations

# %%
data.head(5)

# %%
data.tail(3)

# %%
data.shape

# %%
data.info()

# %%
data.describe(include='all')

# %% [markdown]
# total number of app title contain astrology

# %%
data.columns

# %%
data['App'].str.contains('astrology', case=False).sum()

# %% [markdown]
# find avg app rating

# %%
data['Rating'].mean()

# %% [markdown]
# total number of category

# %%
data['Category'].nunique()

# %% [markdown]
# which category has the highest average rating

# %%
data.groupby('Category')['Rating'].mean().sort_values(ascending=False)

# %% [markdown]
# total apps having 5 star rating

# %%
data.columns

# %%
len(data[data['Rating']==5.0])

# %% [markdown]
# find average value of reviews

# %%
data[data['Reviews']=='3.0M']

# %%
data['Reviews']= data['Reviews'].replace('3.0M',3.0)

# %%
data['Reviews'] = data['Reviews'].astype('float')

# %%
data['Reviews'].mean()

# %% [markdown]
# find total number of free and paid apps

# %%
data.columns

# %%
data['Type'].value_counts()

# %% [markdown]
# which app has max reviews

# %%
data[data['Reviews'].max() == data['Reviews']]

# %% [markdown]
# top 5 app with highest reviews

# %%
index = data['Reviews'].sort_values(ascending=False).head(5).index

# %%
data.iloc[index]

# %% [markdown]
# average rating of paid apps and free apps

# %%
data.groupby('Type')['Rating'].mean()

# %% [markdown]
# display top 5 apps having max installations

# %%
data['Installs'].dtype
# Out:
# dtype('O')

# %% [markdown]
# change the datatype of installs to numeric

# %%
data['Installs'] = data['Installs'].str.replace(',', '')

# %% [markdown]
# check if , is removed

# %%
data.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M    10000+  Free     0       Everyone
# 1     967   14M   500000+  Free     0       Everyone
# 2   87510  8.7M  5000000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %% [markdown]
# remove + from installs

# %%
data['Installs'] = data['Installs'].str.replace('+', '')

# %% [markdown]
# check if + is removed

# %%
data.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size Installs  Type Price Content Rating  \
# 0     159   19M    10000  Free     0       Everyone
# 1     967   14M   500000  Free     0       Everyone
# 2   87510  8.7M  5000000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %% [markdown]
# convert installs to integer

# %%
data['Installs'] = data['Installs'].astype('int')
# this shows a error because of data type mismatch free in string

# %% [markdown]
# check rows where data type of installs is not numeric

# %%
data[~data['Installs'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# replace non-numeric values with zero

# %%
data['Installs'] = data['Installs'].replace('Free', 0)

# %% [markdown]
# now change the datatype of installs to numeric

# %%
data['Installs'] = data['Installs'].astype('int')
# done

# %% [markdown]
# now check the top 5 apps names having max installations

# %%
index = data['Installs'].sort_values(ascending=False).head(5).index

# %%
data.iloc[index]['App']
# Out:
# 3896                              Subway Surfers
# 3943                                    Facebook
# 335     Messenger – Text and Video Chat for Free
# 3523                                Google Drive
# 3565                                Google Drive
# Name: App, dtype: object

# %% [markdown]
# W
